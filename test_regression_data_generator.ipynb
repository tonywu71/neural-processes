# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

from dataloader.load_regression_data_uniform import RegressionDataGeneratorUniform

# %% [markdown]
# # DataGenerator

# %%
data_generator = RegressionDataGeneratorUniform(
    iterations=250,
    batch_size=32,
    min_num_context=3,
    max_num_context=20,
    min_num_target=2
)

# %%
data_generator.plot_first_elt_of_random_batch()
# Out:
# (<Figure size 800x500 with 1 Axes>, <AxesSubplot: >)

# %%
for (context_x, context_y, target_x), target_y in data_generator.train_ds.take(5):
    RegressionDataGeneratorUniform.plot_first_elt_of_batch(context_x, context_y, target_x, target_y)
