# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %cd conditional-neural-processes/
# Out:
# /Users/Tony/Desktop/conditional-neural-processes

# %%
from dataloader.load_regression_data_uniform import RegressionDataGeneratorUniform

# %%
data_generator = RegressionDataGeneratorUniform(
    iterations=250,
    batch_size=32,
    min_num_context=3,
    max_num_context=20,
    min_num_target=2
)
# Out:
# Metal device set to: Apple M1
# 2023-02-08 13:57:22.591489: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-08 13:57:22.592130: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
data_generator.plot_random_batch()
# Out:
# 2023-02-08 13:57:24.610243: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# (<Figure size 800x500 with 1 Axes>, <AxesSubplot: >)

# %%
for (context_x, context_y, target_x), target_y in data_generator.train_ds.take(5):
    RegressionDataGeneratorUniform.plot_batch(context_x, context_y, target_x, target_y)
