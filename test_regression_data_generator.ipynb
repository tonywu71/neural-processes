# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dataloader.load_regression_data import RegressionDataGenerator

# %%
data_generator = RegressionDataGenerator(
    iterations=250,
    batch_size=32,
    min_num_context=3,
    max_num_context=20,
    min_num_target=2
)

# %%
data_generator.plot_random_batch()
# Out:
# (<Figure size 800x500 with 1 Axes>, <AxesSubplot: >)

# %%
for (context_x, context_y, target_x), target_y in data_generator.train_ds.take(5):
    RegressionDataGenerator.plot_batch(context_x, context_y, target_x, target_y)
